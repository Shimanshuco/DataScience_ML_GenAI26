# %% [markdown]
# # Data Gathering with API
# <a href="https://docs.foursquare.com/"> Visit Foursquare </a>

# %%
# API is used to retrieve and update information about places available in the Foursquare Places Dataset.

# %% [markdown]
# | Parameter  | Example                | Purpose                     |
# | ---------- | ---------------------- | --------------------------- |
# | `query`    | `pizza`                | Search text                 |
# | `ll`       | `28.6139,77.2090`      | Latitude,Longitude          |
# | `radius`   | `5000`                 | Search radius in meters     |
# | `limit`    | `20`                   | Maximum results             |
# | `sort`     | `DISTANCE`             | Sort by distance            |
# | `near`     | `Jaipur`               | Search around a city        |
# | `open_now` | `true`                 | Only open places            |
# | `fields`   | `fsq_id,name,location` | Return only selected fields |

# %%
import requests

# %%
url = "https://places-api.foursquare.com/places/search"

headers = {
    "X-Places-Api-Version": "2025-06-17",
    "accept": "application/json",
    "authorization": "Bearer "
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"message":"Invalid request token."}

# %% [markdown]
# # Place Search
#
# **Method:** `GET`
#
# **Endpoint:**
#
# ```http
# https://places-api.foursquare.com/places/search
# ```

# %%
q = 'coffee'
latlon="26.9124,75.7873"

url = f'https://places-api.foursquare.com/places/search?query={q}&ll={latlon}'
url
# Out:
# 'https://places-api.foursquare.com/places/search?query=coffee&ll=26.9124,75.7873'

# %%
headers = {
    "X-Places-Api-Version": "2025-06-17",
    "accept": "application/json",
    "authorization": "Bearer PJA3TFVG2BXDMK1HFW3WNMO30AVBOZ3VUIZ5OS3IPK5UIMZC"
}

# %%
response2 = requests.get(url, headers=headers)
print(response2.json())
# Out:
# {'results': [{'fsq_place_id': '5246f1ad11d24dc900bfdf3b', 'latitude': 26.911575223997577, 'longitude': 75.78904121641247, 'categories': [{'fsq_category_id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'short_name': 'Café', 'plural_name': 'Cafés', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'date_created': '2013-09-28', 'date_refreshed': '2018-05-20', 'distance': 195, 'email': 'info@taruveda.com', 'extended_location': {}, 'link': '/places/5246f1ad11d24dc900bfdf3b', 'location': {'address': 'Jacob Road', 'locality': 'Jaipur', 'region': 'Rājasthān', 'postcode': '', 'country': 'IN', 'formatted_address': 'Jacob Road (Civil Lines), Jaipur, Rājasthān'}, 'name': 'Taruveda', 'placemaker_url': 'https://foursquare.com/placemakers/review-place/5246f1ad11d24dc900bfdf3b', 'related_places': {}, 'social_media': {'twitter': ''}, 'tel': '0141 222 2644', 'website': 'http://taruveda.com'}, {'fsq_place_id': '50081e28e4b05eac5b27a1e9', 'latitude': 26.9156779
# ...

# %%
import pandas as pd

data = response2.json()

rows = []

for place in data["results"]:
    rows.append({
        "Name": place.get("name"),
        "Category": place.get("categories", [{}])[0].get("name", "N/A"),
        "Distance (m)": place.get("distance"),
        "Address": place.get("location", {}).get("formatted_address"),
        "Latitude": place.get("latitude"),
        "Longitude": place.get("longitude"),
        "Phone": place.get("tel"),
        "Website": place.get("website"),
        "Place ID": place.get("fsq_place_id")
    })

df = pd.DataFrame(rows)

df
# Out:
#                            Name     Category  Distance (m)  \
# 0                      Taruveda         Café           195
# 1  NIBS- The Chocolate Workshop         Café           849
# 2                     Mr. Beans         Café          1048
# 3  Curious Life Coffee Roasters         Café          1341
# 4                   Anokhi Cafe         Café          1124
# 5                     Starbucks  Coffee Shop           807
# 6                    White Sage         Café           484
# 7                 Rasta The Way         Café           590
# 8                      Cafe Bae         Café          1498
# 9    Blue Tokai Coffee Roasters         Café           817
#
#                                              Address   Latitude  Longitude  \
# 0        Jacob Road (Civil Lines), Jaipur, Rājasthān  26.911575  75.789041
# 1                                          Rājasthān  26.915678  75.795043
# 2                                  Jaipur, Rājasthān  26.905093  75.793994
# ...
