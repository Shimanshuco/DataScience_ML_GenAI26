# %% [markdown]
# # Gather data through API

# %%
# API : Application programming interface

# %%
import pandas as pd
import requests

# %%
url = 'https://pokeapi.co/api/v2/pokemon/ditto'

# %%
response = requests.get(url)

# %%
response.json()['abilities']
# Out:
# [{'ability': {'name': 'limber', 'url': 'https://pokeapi.co/api/v2/ability/7/'},
#   'is_hidden': False,
#   'slot': 1},
#  {'ability': {'name': 'imposter',
#    'url': 'https://pokeapi.co/api/v2/ability/150/'},
#   'is_hidden': True,
#   'slot': 3}]

# %%
df = pd.DataFrame(response.json()['abilities'])
df
# Out:
#                                              ability  is_hidden  slot
# 0  {'name': 'limber', 'url': 'https://pokeapi.co/...      False     1
# 1  {'name': 'imposter', 'url': 'https://pokeapi.c...       True     3

# %%
# GFG

# %%
url='https://www.geeksforgeeks.org/'

# %%
res = requests.get(url)

# %%
res.reason
# Out:
# 'OK'

# %%
res.status_code
# Out:
# 200

# %%
res.content[0:400]
# Out:
# b'<!DOCTYPE html><html lang="en"><head><script type="application/ld+json">{"@context":"http://schema.org","@type":"Organization","name":"GeeksforGeeks","url":"https://www.geeksforgeeks.org/","logo":"https://media.geeksforgeeks.org/wp-content/cdn-uploads/20200817185016/gfg_complete_logo_2x-min.png","description":"Your All-in-One Learning Portal. It contains well written, well thought and well explain'

# %%
url='https://yt3.googleusercontent.com/uj6zacTRlE5EDFN8yD7bRMmSBO0SE3EofkN_Nju7VXPVICinEYfqg3X-Xe4OLI7geNk2ZzXhEg=s900-c-k-c0x00ffffff-no-rj'

# %%
ri = requests.get(url)
ri
# Out:
# <Response [200]>

# %%
data = ri.content
data[0:100]
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe2\x0b\xf8ICC_PROFILE\x00\x01\x01\x00\x00\x0b\xe8\x00\x00\x00\x00\x02\x00\x00\x00mntrRGB XYZ \x07\xd9\x00\x03\x00\x1b\x00\x15\x00$\x00\x1facsp\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00'

# %%
file = open('img1.jpeg','wb')
file.write(data)
file.close()

# %%
url='https://webhook.site/83d99e4e-b25d-4ff6-bb1d-67356326731c'

# %%
d = {'name':'Himanshu','age':21,'graade':'A+'}
d
# Out:
# {'name': 'Himanshu', 'age': 21, 'graade': 'A+'}

# %%
requests.post(url,json=d)
# Out:
# <Response [200]>

# %%
# https://openweathermap.org/

# %%
key='7546e7e48063e7a6a5b771d7d78c292b'

# %%
# jaipur 
lat = 26.9124
lon = 75.7873

# %%
url=f'https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={key}'
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?lat=26.9124&lon=75.7873&appid=7546e7e48063e7a6a5b771d7d78c292b'

# %% [markdown]
# ### Arguments
# | Parameter | Required | Description |
# |-----------|----------|-------------|
# | `lat` | Yes | Latitude. If you need to automatically convert city names and ZIP codes to geographic coordinates (and vice versa), use the Geocoding API. |
# | `lon` | Yes | Longitude. If you need to automatically convert city names and ZIP codes to geographic coordinates (and vice versa), use the Geocoding API. |
# | `appid` | Yes | Your unique API key. You can find it on your account page under the **API key** tab. |
# | `mode` | No | Response format. Possible values are `json` (default), `xml`, and `html`. |
# | `units` | No | Units of measurement. Available values are `standard` (default), `metric`, and `imperial`. |
# | `lang` | No | Language code for the response. Use this parameter to receive the output in your preferred language. |

# %%
res = requests.get(url)
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'coord': {'lon': 75.7873, 'lat': 26.9124},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 309.39,
#   'feels_like': 310.8,
#   'temp_min': 309.39,
#   'temp_max': 309.39,
#   'pressure': 1003,
#   'humidity': 34,
#   'sea_level': 1003,
#   'grnd_level': 957},
#  'visibility': 10000,
#  'wind': {'speed': 4.24, 'deg': 273, 'gust': 3.31},
#  'clouds': {'all': 52},
#  'dt': 1784356081,
#  'sys': {'country': 'IN', 'sunrise': 1784333619, 'sunset': 1784382723},
#  'timezone': 19800,
#  'id': 8199371,
#  'name': 'Rambagh',
#  'cod': 200}

# %%
temp = res.json()['main']['temp']
print("Temp ",temp)
temp = res.json()['main']['temp_min']
print("Min. Temp ",temp)
# Out:
# Temp  309.39
# Min. Temp  309.39

# %%
# using city name
city_name='jaipur'
url2=f'https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={key}'
url2
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=jaipur&appid=7546e7e48063e7a6a5b771d7d78c292b'

# %%
res2 =  requests.get(url2)
res2
# Out:
# <Response [200]>

# %%
res2.json()
# Out:
# {'coord': {'lon': 75.8167, 'lat': 26.9167},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 309.96,
#   'feels_like': 311.49,
#   'temp_min': 309.96,
#   'temp_max': 309.96,
#   'pressure': 1002,
#   'humidity': 33,
#   'sea_level': 1002,
#   'grnd_level': 955},
#  'visibility': 10000,
#  'wind': {'speed': 3.54, 'deg': 268, 'gust': 2.54},
#  'clouds': {'all': 100},
#  'dt': 1784357390,
#  'sys': {'country': 'IN', 'sunrise': 1784333611, 'sunset': 1784382716},
#  'timezone': 19800,
#  'id': 1269515,
#  'name': 'Jaipur',
#  'cod': 200}

# %%
# in f 
# units : Units of measurement. standard, metric and imperial units are available. 
# If you do not use the units parameter, standard units will be applied by default.

city_name='jaipur'
url2=f'https://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={key}&units=metric'
url2
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=jaipur&appid=7546e7e48063e7a6a5b771d7d78c292b&units=metric'

# %%
res3 =  requests.get(url2)
res3
# Out:
# <Response [200]>

# %%
res3.json()
# Out:
# {'coord': {'lon': 75.8167, 'lat': 26.9167},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 36.81,
#   'feels_like': 38.34,
#   'temp_min': 36.81,
#   'temp_max': 36.81,
#   'pressure': 1002,
#   'humidity': 33,
#   'sea_level': 1002,
#   'grnd_level': 955},
#  'visibility': 10000,
#  'wind': {'speed': 3.54, 'deg': 268, 'gust': 2.54},
#  'clouds': {'all': 100},
#  'dt': 1784357779,
#  'sys': {'country': 'IN', 'sunrise': 1784333611, 'sunset': 1784382716},
#  'timezone': 19800,
#  'id': 1269515,
#  'name': 'Jaipur',
#  'cod': 200}

# %%
def get_weather():
    city_name = input("Enter city name: ").strip()

    url = (
        f"https://api.openweathermap.org/data/2.5/weather"
        f"?q={city_name}&appid={key}&units=metric"
    )

    try:
        response = requests.get(url)
        response.raise_for_status()

        data = response.json()

        city = data["name"]
        country = data["sys"]["country"]

        temp = data["main"]["temp"]
        temp_min = data["main"]["temp_min"]
        temp_max = data["main"]["temp_max"]
        weather = data["weather"][0]["description"]

        print("\n===== Weather Report =====")
        print(f"City        : {city}, {country}")
        print(f"Weather     : {weather.title()}")
        print(f"Temperature : {temp:.1f}°C")
        print(f"Min Temp    : {temp_min:.1f}°C")
        print(f"Max Temp    : {temp_max:.1f}°C")

    except requests.exceptions.HTTPError:
        print("City not found. Please enter a valid city name.")
    except Exception as e:
        print("Error:", e)


# Call the function
get_weather()
# Out:
# Enter city name:  jaipur
# ===== Weather Report =====
# City        : Jaipur, IN
# Weather     : Overcast Clouds
# Temperature : 36.8°C
# Min Temp    : 36.8°C
# Max Temp    : 36.8°C
